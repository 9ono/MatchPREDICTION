# %%
import pandas as pd

match_df = pd.read_csv('all_match_with_gap.csv', index_col = 0)
match_df.head()
# Out:
#    Score  Rating  Total_shot  Woodwork  Shot_onTarget  Shot_offTarget  \
# 0      1    0.24           5         1              5              -2
# 1      1    0.43           4         0              3               0
# 2      0   -0.15          -8        -2             -2               0
# 3      2    0.88          10         0              5               4
# 4     -2   -0.49          19         0              3              10
#
#    Shot_blocked  Possession  Touches  Pass%  ...  Corner  Corner%  Disposs  \
# 0             2       -32.2     -293    -14  ...       1       15        2
# 1             1        -2.2       -8      0  ...       2        9        2
# 2            -6       -19.6     -166     -8  ...      -5      -30       -5
# 3             1        -2.8      -49     -4  ...       6       63      -13
# 4             6        29.6      265     18  ...      -1        5      -11
#
#    Err  Foul  Offside  W  D  L  Result
# 0   -2     5        3  1  0  0       W
# ...

# %%
max_gap = match_df[['Rating', 'Total_shot', 'Woodwork', 'Shot_onTarget',
       'Shot_offTarget', 'Shot_blocked', 'Possession', 'Touches', 'Pass%',
       'Total_pass', 'Acc_pass', 'Key_pass', 'Dribble_won', 'Dribble_att',
       'Dribbled_past', 'Dribble%', 'Aerial_won', 'Aerial_won%', 'Off_aerial',
       'Def_aerial', 'Succ_Tack', 'Tack_att', 'Was_dribbled', 'Tack%',
       'Clearance', 'Intercept', 'Corner', 'Corner%', 'Disposs', 'Err', 'Foul',
       'Offside']].max()
min_gap = match_df[['Rating', 'Total_shot', 'Woodwork', 'Shot_onTarget',
       'Shot_offTarget', 'Shot_blocked', 'Possession', 'Touches', 'Pass%',
       'Total_pass', 'Acc_pass', 'Key_pass', 'Dribble_won', 'Dribble_att',
       'Dribbled_past', 'Dribble%', 'Aerial_won', 'Aerial_won%', 'Off_aerial',
       'Def_aerial', 'Succ_Tack', 'Tack_att', 'Was_dribbled', 'Tack%',
       'Clearance', 'Intercept', 'Corner', 'Corner%', 'Disposs', 'Err', 'Foul',
       'Offside']].min()

# %%
print(list(max_gap))
print(list(min_gap))
# Out:
# [2.77, 38.0, 3.0, 17.0, 19.0, 14.0, 61.6, 644.0, 37.0, 628.0, 635.0, 30.0, 20.0, 30.0, 21.0, 71.0, 22.0, 70.0, 41.0, 24.0, 24.0, 41.0, 21.0, 61.0, 43.0, 16.0, 19.0, 100.0, 20.0, 4.0, 15.0, 9.0]
# [-2.9300000000000006, -27.0, -3.0, -15.0, -15.0, -13.0, -56.8, -585.0, -43.0, -562.0, -565.0, -25.0, -21.0, -29.0, -20.0, -75.0, -23.0, -72.0, -24.0, -41.0, -24.0, -35.0, -20.0, -57.0, -71.0, -24.0, -13.0, -100.0, -19.0, -3.0, -18.0, -8.0]

# %%
len(max_gap)
# Out:
# 32

# %%
from sklearn import preprocessing
x = match_df[['Score', 'Rating', 'Total_shot', 'Woodwork', 'Shot_onTarget',
       'Shot_offTarget', 'Shot_blocked', 'Possession', 'Touches', 'Pass%',
       'Total_pass', 'Acc_pass', 'Key_pass', 'Dribble_won', 'Dribble_att',
       'Dribbled_past', 'Dribble%', 'Aerial_won', 'Aerial_won%', 'Off_aerial',
       'Def_aerial', 'Succ_Tack', 'Tack_att', 'Was_dribbled', 'Tack%',
       'Clearance', 'Intercept', 'Corner', 'Corner%', 'Disposs', 'Err', 'Foul',
       'Offside', 'W', 'D', 'L']].values.astype(float)
       
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)

df = pd.DataFrame(x_scaled, columns = ['Score', 'Rating', 'Total_shot', 'Woodwork', 'Shot_onTarget',
       'Shot_offTarget', 'Shot_blocked', 'Possession', 'Touches', 'Pass%',
       'Total_pass', 'Acc_pass', 'Key_pass', 'Dribble_won', 'Dribble_att',
       'Dribbled_past', 'Dribble%', 'Aerial_won', 'Aerial_won%', 'Off_aerial',
       'Def_aerial', 'Succ_Tack', 'Tack_att', 'Was_dribbled', 'Tack%',
       'Clearance', 'Intercept', 'Corner', 'Corner%', 'Disposs', 'Err', 'Foul',
       'Offside', 'W', 'D', 'L'])

# %%
df.head()
# Out:
#       Score    Rating  Total_shot  Woodwork  Shot_onTarget  Shot_offTarget  \
# 0  0.588235  0.556140    0.492308  0.666667        0.62500        0.382353
# 1  0.588235  0.589474    0.476923  0.500000        0.56250        0.441176
# 2  0.529412  0.487719    0.292308  0.166667        0.40625        0.441176
# 3  0.647059  0.668421    0.569231  0.500000        0.62500        0.558824
# 4  0.411765  0.428070    0.707692  0.500000        0.56250        0.735294
#
#    Shot_blocked  Possession   Touches   Pass%  ...  Intercept   Corner  \
# 0      0.555556    0.207770  0.237592  0.3625  ...      0.600  0.43750
# 1      0.518519    0.461149  0.469487  0.5375  ...      0.625  0.46875
# 2      0.259259    0.314189  0.340928  0.4375  ...      0.525  0.25000
# 3      0.518519    0.456081  0.436127  0.4875  ...      0.700  0.59375
# 4      0.703704    0.729730  0.691619  0.7625  ...      0.450  0.37500
#
#    Corner%   Disposs       Err      Foul   Offside    W    D    L
# ...

# %%
df = df[['Rating', 'Total_shot', 'Woodwork', 'Shot_onTarget',
       'Shot_offTarget', 'Shot_blocked', 'Possession', 'Touches', 'Pass%',
       'Total_pass', 'Acc_pass', 'Key_pass', 'Dribble_won', 'Dribble_att',
       'Dribbled_past', 'Dribble%', 'Aerial_won', 'Aerial_won%', 'Off_aerial',
       'Def_aerial', 'Succ_Tack', 'Tack_att', 'Was_dribbled', 'Tack%',
       'Clearance', 'Intercept', 'Corner', 'Corner%', 'Disposs', 'Err', 'Foul',
       'Offside', 'W', 'D', 'L']]

# %%
df.head()
# Out:
#      Rating  Total_shot  Woodwork  Shot_onTarget  Shot_offTarget  \
# 0  0.556140    0.492308  0.666667        0.62500        0.382353
# 1  0.589474    0.476923  0.500000        0.56250        0.441176
# 2  0.487719    0.292308  0.166667        0.40625        0.441176
# 3  0.668421    0.569231  0.500000        0.62500        0.558824
# 4  0.428070    0.707692  0.500000        0.56250        0.735294
#
#    Shot_blocked  Possession   Touches   Pass%  Total_pass  ...  Intercept  \
# 0      0.555556    0.207770  0.237592  0.3625    0.236975  ...      0.600
# 1      0.518519    0.461149  0.469487  0.5375    0.443697  ...      0.625
# 2      0.259259    0.314189  0.340928  0.4375    0.334454  ...      0.525
# 3      0.518519    0.456081  0.436127  0.4875    0.450420  ...      0.700
# 4      0.703704    0.729730  0.691619  0.7625    0.685714  ...      0.450
#
#     Corner  Corner%   Disposs       Err      Foul   Offside    W    D    L
# ...

# %%
print(df['W'].sum())
print(df['D'].sum())
print(df['L'].sum())
# Out:
# 737.0
# 363.0
# 435.0

# %%
import numpy as np
nd = np.array(df)
ndd = []

# %%
#66 67 68
w_sum = 0
d_sum = 0
l_sum = 0
for i in nd:
    if i[32] == 1 and w_sum < 360:
        w_sum += 1
        ndd.append(list(i))
    elif i[34] == 1 and l_sum < 360:
        l_sum += 1
        ndd.append(list(i))
    elif i[33] == 1 and d_sum < 360:
        d_sum += 1
        ndd.append(list(i))

# %%
len(ndd)
# Out:
# 1080

# %%
new_df = pd.DataFrame(ndd, columns = ['Rating', 'Total_shot', 'Woodwork', 'Shot_onTarget',
       'Shot_offTarget', 'Shot_blocked', 'Possession', 'Touches', 'Pass%',
       'Total_pass', 'Acc_pass', 'Key_pass', 'Dribble_won', 'Dribble_att',
       'Dribbled_past', 'Dribble%', 'Aerial_won', 'Aerial_won%', 'Off_aerial',
       'Def_aerial', 'Succ_Tack', 'Tack_att', 'Was_dribbled', 'Tack%',
       'Clearance', 'Intercept', 'Corner', 'Corner%', 'Disposs', 'Err', 'Foul',
       'Offside', 'W', 'D', 'L'])

# %%
print(len(new_df))
# Out:
# 1080

# %%
new_df.head()
# Out:
#      Rating  Total_shot  Woodwork  Shot_onTarget  Shot_offTarget  \
# 0  0.556140    0.492308  0.666667        0.62500        0.382353
# 1  0.589474    0.476923  0.500000        0.56250        0.441176
# 2  0.487719    0.292308  0.166667        0.40625        0.441176
# 3  0.668421    0.569231  0.500000        0.62500        0.558824
# 4  0.428070    0.707692  0.500000        0.56250        0.735294
#
#    Shot_blocked  Possession   Touches   Pass%  Total_pass  ...  Intercept  \
# 0      0.555556    0.207770  0.237592  0.3625    0.236975  ...      0.600
# 1      0.518519    0.461149  0.469487  0.5375    0.443697  ...      0.625
# 2      0.259259    0.314189  0.340928  0.4375    0.334454  ...      0.525
# 3      0.518519    0.456081  0.436127  0.4875    0.450420  ...      0.700
# 4      0.703704    0.729730  0.691619  0.7625    0.685714  ...      0.450
#
#     Corner  Corner%   Disposs       Err      Foul   Offside    W    D    L
# ...

# %%
def data_split(df, attrs):
    from sklearn.model_selection import train_test_split
    
    x = df.loc[:,attrs]
    y = df[['W', 'D', 'L']]
    
    x_train, x_test, t_train, t_test = train_test_split(x, y, test_size=0.30, random_state = None)
    return x_train, x_test, t_train, t_test

# %%
x_train, x_test, t_train, t_test = data_split(new_df, ['Rating', 'Total_shot', 'Woodwork', 'Shot_onTarget',
       'Shot_offTarget', 'Shot_blocked', 'Possession', 'Touches', 'Pass%',
       'Total_pass', 'Acc_pass', 'Key_pass', 'Dribble_won', 'Dribble_att',
       'Dribbled_past', 'Dribble%', 'Aerial_won', 'Aerial_won%', 'Off_aerial',
       'Def_aerial', 'Succ_Tack', 'Tack_att', 'Was_dribbled', 'Tack%',
       'Clearance', 'Intercept', 'Corner', 'Corner%', 'Disposs', 'Err', 'Foul',
       'Offside'])

# %%
print('-------train------')
print(t_train['W'].sum())
print(t_train['D'].sum())
print(t_train['L'].sum())
print('-------test------')
print(t_test['W'].sum())
print(t_test['D'].sum())
print(t_test['L'].sum())
# Out:
# -------train------
# 250.0
# 252.0
# 254.0
# -------test------
# 110.0
# 108.0
# 106.0

# %%
x_train = np.array(x_train)
x_test = np.array(x_test)
t_train = np.array(t_train)
t_test = np.array(t_test)

# %% [markdown]
# # neural net coding

# %%
import sys, os
import numpy as np
from collections import OrderedDict

# %%
class Relu:
    def __init__(self):
        self.mask = None

    def forward(self, x):
        self.mask = (x <= 0)
        out = x.copy()
        out[self.mask] = 0

        return out

    def backward(self, dout):
        dout[self.mask] = 0
        dx = dout

        return dx

# %%
class Affine:
    def __init__(self, W, b):
        self.W = W
        self.b = b
        
        self.x = None
        self.original_x_shape = None
        # 가중치와 편향 매개변수의 미분
        self.dW = None
        self.db = None

    def forward(self, x):
        # 텐서 대응
        self.original_x_shape = x.shape
        x = x.reshape(x.shape[0], -1)
        self.x = x

        out = np.dot(self.x, self.W) + self.b

        return out

    def backward(self, dout):
        dx = np.dot(dout, self.W.T)
        self.dW = np.dot(self.x.T, dout)
        self.db = np.sum(dout, axis=0)
        
        dx = dx.reshape(*self.original_x_shape)  # 입력 데이터 모양 변경(텐서 대응)
        return dx

# %%
def softmax(x):
    if x.ndim == 2:
        x = x.T
        x = x - np.max(x, axis=0)
        y = np.exp(x) / np.sum(np.exp(x), axis=0)
        return y.T 

    x = x - np.max(x) # 오버플로 대책
    return np.exp(x) / np.sum(np.exp(x))

# %%
def cross_entropy_error(y, t):
    if y.ndim == 1:
        t = t.reshape(1, t.size)
        y = y.reshape(1, y.size)
        
    # 훈련 데이터가 원-핫 벡터라면 정답 레이블의 인덱스로 반환
    if t.size == y.size:
        t = t.argmax(axis=1)
             
    batch_size = y.shape[0]
    return -np.sum(np.log(y[np.arange(batch_size), t] + 1e-7)) / batch_size

# %%
class SoftmaxWithLoss:
    def __init__(self):
        self.loss = None # 손실함수
        self.y = None    # softmax의 출력
        self.t = None    # 정답 레이블(원-핫 인코딩 형태)
        
    def forward(self, x, t):
        self.t = t
        self.y = softmax(x)
        self.loss = cross_entropy_error(self.y, self.t)
        
        return self.loss

    def backward(self, dout=1):
        batch_size = self.t.shape[0]
        if self.t.size == self.y.size: # 정답 레이블이 원-핫 인코딩 형태일 때
            dx = (self.y - self.t) / batch_size
        else:
            dx = self.y.copy()
            dx[np.arange(batch_size), self.t] -= 1
            dx = dx / batch_size
        
        return dx

# %%
def mean_squared_error(y, t):
    return 0.5 * np.sum((y-t)**2)

# %%
class SoftmaxWithLossMSE:
    def __init__(self):
        self.loss = None # 손실함수
        self.y = None    # softmax의 출력
        self.t = None    # 정답 레이블(원-핫 인코딩 형태)
        
    def forward(self, x, t):
        self.t = t
        self.y = softmax(x)
        self.loss = mean_squared_error(self.y, self.t)
        
        return self.loss

    def backward(self, dout=1):
        batch_size = self.t.shape[0]
        if self.t.size == self.y.size: # 정답 레이블이 원-핫 인코딩 형태일 때
            dx = (self.y - self.t) / batch_size
        else:
            dx = self.y.copy()
            dx[np.arange(batch_size), self.t] -= 1
            dx = dx / batch_size
        
        return dx

# %%
def numerical_gradient(f, x):
    h = 1e-4 # 0.0001
    grad = np.zeros_like(x)
    
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:
        idx = it.multi_index
        tmp_val = x[idx]
        x[idx] = float(tmp_val) + h
        fxh1 = f(x) # f(x+h)
        
        x[idx] = tmp_val - h 
        fxh2 = f(x) # f(x-h)
        grad[idx] = (fxh1 - fxh2) / (2*h)
        
        x[idx] = tmp_val # 값 복원
        it.iternext()   
        
    return grad

# %%
class LayerNet_g:

    def __init__(self, input_size, hidden01_size, hidden02_size, hidden03_size, output_size, weight_init_std=0.01):
        # 가중치 초기화
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(input_size, hidden01_size)
        self.params['b1'] = np.zeros(hidden01_size)
        self.params['W2'] = weight_init_std * np.random.randn(hidden01_size, hidden02_size)
        self.params['b2'] = np.zeros(hidden02_size)
        self.params['W3'] = weight_init_std * np.random.randn(hidden02_size, hidden03_size)
        self.params['b3'] = np.zeros(hidden03_size)
        self.params['W4'] = weight_init_std * np.random.randn(hidden03_size, output_size)
        self.params['b4'] = np.zeros(output_size)
        
        # 계층 생성
        self.layers = OrderedDict()
        
        #relu layer
        self.layers['Affine1'] = Affine(self.params['W1'], self.params['b1'])
        self.layers['Relu1'] = Relu()
        self.layers['Affine2'] = Affine(self.params['W2'], self.params['b2'])
        self.layers['Relu2'] = Relu()
        self.layers['Affine3'] = Affine(self.params['W3'], self.params['b3'])
        self.layers['Relu3'] = Relu()
        self.layers['Affine4'] = Affine(self.params['W4'], self.params['b4'])
        
        #self.lastLayer = SoftmaxWithLossMSE()
        self.lastLayer = SoftmaxWithLoss()
        
    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)
        
        return x
        
    # x : 입력 데이터, t : 정답 레이블
    def loss(self, x, t):
        y = self.predict(x)
        return self.lastLayer.forward(y, t)
    
    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        if t.ndim != 1 : t = np.argmax(t, axis=1)
        
        accuracy = np.sum(y == t) / float(x.shape[0])
        return accuracy
        
    # x : 입력 데이터, t : 정답 레이블
    def numerical_gradient(self, x, t):
        loss_W = lambda W: self.loss(x, t)
        
        grads = {}
        grads['W1'] = numerical_gradient(loss_W, self.params['W1'])
        grads['b1'] = numerical_gradient(loss_W, self.params['b1'])
        grads['W2'] = numerical_gradient(loss_W, self.params['W2'])
        grads['b2'] = numerical_gradient(loss_W, self.params['b2'])
        grads['W3'] = numerical_gradient(loss_W, self.params['W3'])
        grads['b3'] = numerical_gradient(loss_W, self.params['b3'])
        grads['W4'] = numerical_gradient(loss_W, self.params['W4'])
        grads['b4'] = numerical_gradient(loss_W, self.params['b4'])
        
        return grads
        
    def gradient(self, x, t):
        # forward
        self.loss(x, t)

        # backward
        dout = 1
        dout = self.lastLayer.backward(dout)
        
        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 결과 저장
        grads = {}
        grads['W1'], grads['b1'] = self.layers['Affine1'].dW, self.layers['Affine1'].db
        grads['W2'], grads['b2'] = self.layers['Affine2'].dW, self.layers['Affine2'].db
        grads['W3'], grads['b3'] = self.layers['Affine3'].dW, self.layers['Affine3'].db
        grads['W4'], grads['b4'] = self.layers['Affine4'].dW, self.layers['Affine4'].db

        return grads

# %%
x_train.shape
# Out:
# (602, 36)

# %%
batch_size = 100
iter_per_epoch = max(train_size / batch_size, 1)
iter_per_epoch
# Out:
# 6.02

# %%
import matplotlib.pyplot as plt

network = LayerNet_g(input_size = 33, hidden01_size = 50, hidden02_size = 20, hidden03_size = 30, output_size = 2)

iters_num = 10000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1
loss = 10
i = 0

train_loss_list = []
test_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
iter_per_epoch += -0.02

while i < iters_num:
    #print(i)
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    # 기울기 계산
    #grad = network.numerical_gradient(x_batch, t_batch) # 수치 미분 방식
    grad = network.gradient(x_batch, t_batch) # 오차역전파법 방식(훨씬 빠르다)
    
    # 갱신
    for key in ('W1', 'b1', 'W2', 'b2', 'W3', 'b3', 'W4', 'b4'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)
    test_loss = network.loss(x_test, t_test)
    test_loss_list.append(test_loss)
    
    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        
        print('train acc | ' + str(train_acc) + ' test acc | ' + str(test_acc))
        print('loss | ' + str(loss))
    
    i += 1
# Out:
# train acc | 0.5016611295681063 test acc | 0.49612403100775193
# loss | 0.6926590369911919
# train acc | 0.5016611295681063 test acc | 0.49612403100775193
# loss | 0.6930583924703064
# train acc | 0.4983388704318937 test acc | 0.5038759689922481
# loss | 0.693141088006241
# train acc | 0.4983388704318937 test acc | 0.5038759689922481
# loss | 0.693168957874795
# train acc | 0.4983388704318937 test acc | 0.5038759689922481
# loss | 0.6932902976871702
# train acc | 0.5016611295681063 test acc | 0.49612403100775193
# loss | 0.6930453089698482
# train acc | 0.5016611295681063 test acc | 0.49612403100775193
# loss | 0.6933768382420995
# train acc | 0.5016611295681063 test acc | 0.49612403100775193
# loss | 0.6930357618140252
# train acc | 0.5016611295681063 test acc | 0.49612403100775193
# loss | 0.691131822718383
# train acc | 0.5016611295681063 test acc | 0.49612403100775193
# loss | 0.6925848133480226
# train acc | 0.5016611295681063 test acc | 0.49612403100775193
# ...

# %% [markdown]
# # neural net keras

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

# %%
model = Sequential()
model.add(Dense(50, input_dim=32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


#hist = model.fit(x_train, t_train, epochs=1000, batch_size=100)
hist = model.fit(x_train, t_train, validation_data = (x_test, t_test), epochs = 2500, batch_size = 100)
# Out:
# Train on 756 samples, validate on 324 samples
# Epoch 1/2500
# 756/756 [==============================] - 1s 1ms/step - loss: 1.1324 - acc: 0.3241 - val_loss: 1.1010 - val_acc: 0.3302
# Epoch 2/2500
# 756/756 [==============================] - 0s 30us/step - loss: 1.1215 - acc: 0.3108 - val_loss: 1.0990 - val_acc: 0.3179
# Epoch 3/2500
# 756/756 [==============================] - 0s 29us/step - loss: 1.1157 - acc: 0.3056 - val_loss: 1.0984 - val_acc: 0.3056
# Epoch 4/2500
# 756/756 [==============================] - 0s 36us/step - loss: 1.1050 - acc: 0.3228 - val_loss: 1.0983 - val_acc: 0.3241
# Epoch 5/2500
# 756/756 [==============================] - 0s 30us/step - loss: 1.1044 - acc: 0.3029 - val_loss: 1.0980 - val_acc: 0.3395
# Epoch 6/2500
# 756/756 [==============================] - 0s 29us/step - loss: 1.0994 - acc: 0.3598 - val_loss: 1.0980 - val_acc: 0.3673
# Epoch 7/2500
# ...

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(hist.history['acc'], 'b', label='train acc')
acc_ax.plot(hist.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper right')

plt.show()

# %%
from keras.models import load_model

model.save('./match_result_model.h5')

# %%
from keras.models import load_model
model = load_model('./match_result_model.h5')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1213 06:25:02.761484  1996 deprecation_wrapper.py:119] From C:\Users\gono\Anaconda3\envs\ml_scratch\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1213 06:25:02.816443  1996 deprecation_wrapper.py:119] From C:\Users\gono\Anaconda3\envs\ml_scratch\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1213 06:25:02.862415  1996 deprecation_wrapper.py:119] From C:\Users\gono\Anaconda3\envs\ml_scratch\lib\site-packages\keras\backend\tensorflow_backend.py:131: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# ...

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_25 (Dense)             (None, 50)                1650
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                510
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_27 (Dense)             (None, 20)                220
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 3)                 63
# ...
# Total params: 2,443
# ...

# %% [markdown]
# # prediction func

# %%
team_df = pd.read_csv('./team.csv', index_col = 0)
team_df.head(20)
# Out:
#                Team  Score  Rating  Total_shot  Woodwork  Shot_onTarget  \
# 0         Liverpool   2.42    6.99        16.5       0.2            6.3
# 1          Leicster   2.36    7.09        15.0       0.1            5.4
# 2   Manchester City   2.81    7.08        19.5       0.6            6.9
# 3           Chelsea   2.21    6.89        17.4       0.1            6.3
# 4    Manchester Utd   1.57    6.77        13.8       0.3            5.0
# 5      Wolverhamton   1.39    6.78        12.2       0.1            4.3
# 6         Tottenham   2.18    6.84        12.7       0.2            5.5
# 7     Sheffield Utd   1.52    6.75        10.4       0.1            3.6
# 8           Arsenal   1.89    6.80        13.2       0.2            4.7
# 9    Crystal palace   1.00    6.69         9.4       0.0            3.2
# 10        Newcastle   1.19    6.72        10.1       0.1            3.7
# 11         Brighton   1.56    6.68        12.6       0.0            3.9
# ...

# %%
teams = np.array(team_df)

# %%
def make_xhat(home, away):
    h_i = 0
    a_i = 0
    for i in range(len(teams)):
        if home == teams[i][0]:
            h_i = i
        if away == teams[i][0]:
            a_i = i
    #print(h_i, a_i)
    h = list(teams[h_i][2:])
    a = list(teams[a_i][2:])
    #print(h, a)
    xlist = []
    tmp = []
    
    for i in range(len(h)):
        tmp.append(h[i] - a[i])
    
    xlist.append(tmp)
    xlist.append(list(max_gap))
    xlist.append(list(min_gap))
    #print(len(xlist[0]))
    #print(len(xlist[1]))
    #print(len(xlist[2]))
    
    x_df = pd.DataFrame(xlist, columns = ['Rating', 'Total_shot', 'Woodwork', 'Shot_onTarget',
       'Shot_offTarget', 'Shot_blocked', 'Possession', 'Touches', 'Pass%',
       'Total_pass', 'Acc_pass', 'Key_pass', 'Dribble_won', 'Dribble_att',
       'Dribbled_past', 'Dribble%', 'Aerial_won', 'Aerial_won%', 'Off_aerial',
       'Def_aerial', 'Succ_Tack', 'Tack_att', 'Was_dribbled', 'Tack%',
       'Clearance', 'Intercept', 'Corner', 'Corner%', 'Disposs', 'Err', 'Foul',
       'Offside'])
    
    x = x_df.values.astype(float)
    min_max_scaler = preprocessing.MinMaxScaler()
    x_scaled = min_max_scaler.fit_transform(x)
    #print(x_scaled.shape)
    xhat = x_scaled = x_scaled[0:1]
    #print(x_scaled.shape)
    return xhat

# %%
def predict_win(home, away):
    xhat = make_xhat(home, away)
    #print(xhat)
    yhat = model.predict(xhat)
    yhat = list(yhat[0])
    highest_index = yhat.index(max(yhat))
    
    if highest_index == 0:
        print('Home team(' + home + ') is winner. | ', yhat[0])
    elif highest_index == 1:
        print('Draw. | ', yhat[1])
    elif highest_index == 2:
        print('Away team(' + away + ') is winner. | ', yhat[2])

# %% [markdown]
# # real predicton

# %%
match_list = [['Bournemouth', 'Liverpool'],
             ['Tottenham', 'Burnley'],
             ['Watford', 'Crystal palace'],
             ['Manchester City', 'Manchester Utd'],
             ['Aston villa', 'Leicster'],
             ['Newcastle', 'Southamton'],
             ['Norwich', 'Sheffield Utd'],
             ['Brighton', 'Wolverhamton'],
             ['Westham', 'Arsenal']]


# 191208 nine matches list

# %%
for i in match_list:
    predict_win(i[0], i[1])
# Out:
# Away team(Liverpool) is winner. |  0.9604235
# Draw. |  0.96620196
# Away team(Crystal palace) is winner. |  0.9524743
# Draw. |  0.6124765
# Away team(Leicster) is winner. |  0.9505843
# Draw. |  0.72708654
# Draw. |  0.9802018
# Draw. |  0.933994
# Away team(Arsenal) is winner. |  0.5313893

# %%
predict_win('Liverpool', 'Watford')
# Out:
# Home team(Liverpool) is winner. |  1.0

# %%
predict_win('Leicster', 'Liverpool')
# Out:
# Draw. |  0.97999614
